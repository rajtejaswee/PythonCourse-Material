# %% [markdown]
# ### Logging with Multiple Loggers

# %% [markdown]
# You can create multiple loggers for different parts of your application.

# %%
import logging

logger1 = logging.getLogger("module 1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module 2")
logger2.setLevel(logging.WARNING)

# Configure logging settings
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

# %%
# log messages with different loggers   

logger1.debug("This is a debug message from module 1")
logger2.warning("This is a warning message from module 2")
logger2.error("This is an error message from module 2")
# Out:
# 2025-03-31 01:26:48 - module 1 - DEBUG - This is a debug message from module 1
# 2025-03-31 01:26:48 - module 2 - WARNING - This is a warning message from module 2
# 2025-03-31 01:26:48 - module 2 - ERROR - This is an error message from module 2
